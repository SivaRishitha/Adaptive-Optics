# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Mechatronics.csv')

# %%
df
# Out:
#     InDia  arm length  OACD  Arm_angle  Fille_radius      4      5      6  \
# 0      60        42.5     4        8.0             1  70.50  76.80  75.30
# 1      60        42.5     4        8.0             2  68.80  71.40  71.90
# 2      60        42.5     4        8.0             3  68.00  72.90  71.00
# 3      60        42.5     4        8.0             4  65.50  73.00  71.00
# 4      60        42.5     4        8.0             5  62.80  71.50  70.90
# 5      60        40.0     4        7.0             1  72.90  79.70  78.20
# 6      60        40.0     4        7.0             2  70.90  80.50  81.20
# 7      60        40.0     4        7.0             3  73.80  81.00  80.30
# 8      60        40.0     4        7.0             5  73.80  79.20  78.90
# 9      60        40.0     4        9.0             1  71.40  80.10  81.10
# 10     60        40.0     4        9.0             2  71.50  80.60  77.30
# 11     60        40.0     4        9.0             4  72.10  81.10  80.40
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('Unnamed')]
df
# Out:
#     InDia  arm length  OACD  Arm_angle  Fille_radius      4      5      6  \
# 0      60        42.5     4        8.0             1  70.50  76.80  75.30
# 1      60        42.5     4        8.0             2  68.80  71.40  71.90
# 2      60        42.5     4        8.0             3  68.00  72.90  71.00
# 3      60        42.5     4        8.0             4  65.50  73.00  71.00
# 4      60        42.5     4        8.0             5  62.80  71.50  70.90
# 5      60        40.0     4        7.0             1  72.90  79.70  78.20
# 6      60        40.0     4        7.0             2  70.90  80.50  81.20
# 7      60        40.0     4        7.0             3  73.80  81.00  80.30
# 8      60        40.0     4        7.0             5  73.80  79.20  78.90
# 9      60        40.0     4        9.0             1  71.40  80.10  81.10
# 10     60        40.0     4        9.0             2  71.50  80.60  77.30
# 11     60        40.0     4        9.0             4  72.10  81.10  80.40
# ...

# %%
df.isnull().sum()
# Out:
# InDia           0
# arm length      0
# OACD            0
# Arm_angle       0
# Fille_radius    0
# 4               0
# 5               0
# 6               0
# 10              0
# 11              0
# 12              0
# 13              0
# 17              0
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#     InDia  arm length  OACD  Arm_angle  Fille_radius      4      5      6  \
# 0      60        42.5     4        8.0             1  70.50  76.80  75.30
# 1      60        42.5     4        8.0             2  68.80  71.40  71.90
# 2      60        42.5     4        8.0             3  68.00  72.90  71.00
# 3      60        42.5     4        8.0             4  65.50  73.00  71.00
# 4      60        42.5     4        8.0             5  62.80  71.50  70.90
# 5      60        40.0     4        7.0             1  72.90  79.70  78.20
# 6      60        40.0     4        7.0             2  70.90  80.50  81.20
# 7      60        40.0     4        7.0             3  73.80  81.00  80.30
# 8      60        40.0     4        7.0             5  73.80  79.20  78.90
# 9      60        40.0     4        9.0             1  71.40  80.10  81.10
# 10     60        40.0     4        9.0             2  71.50  80.60  77.30
# 11     60        40.0     4        9.0             4  72.10  81.10  80.40
# ...

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of DataFrame')
plt.show()

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error
import numpy as np

# Assume X and Y are your data arrays
X = df[['InDia', 'Arm_angle', 'Fille_radius', 'arm length', 'OACD']]
Y = df[['4', '5', '6', '10', '11', '12', '13', '17']]

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneOut
import numpy as np

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("pca", PCA(n_components=3)),  # try 3 or 4
    ("ridge", RidgeCV(alphas=np.logspace(-3, 3, 25), cv=LeaveOneOut()))
])

pipe.fit(X, Y)
print("Best alpha:", pipe.named_steps['ridge'].alpha_)
print("Score with PCA:", pipe.score(X, Y))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
# ...

# %%
ridge_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("ridge", RidgeCV(alphas=np.logspace(-3, 3, 25), cv=LeaveOneOut()))
])

ridge_pipe.fit(X, Y)
print("Score without PCA:", ridge_pipe.score(X, Y))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
# ...

# %%
import numpy as np
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# try alphas over several orders of magnitude
alphas = np.logspace(-6, 1, 50)

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("ridge_cv", RidgeCV(alphas=alphas,
                         scoring="neg_mean_squared_error",
                         cv=LeaveOneOut()))
])

# For multi-output, RidgeCV handles it directly
pipe.fit(X, Y)
print("Best α:", pipe.named_steps["ridge_cv"].alpha_)
print("CV MSE:", -pipe.score(X, Y))
# Out:
# Best α: 5.179474679231202
# CV MSE: -0.6618579340411703

# %%
model = Ridge(alpha=5.179474679231202)  # alpha is L2 regularization strength
model.fit(X, Y)

# Predict
Y_pred = model.predict(X)
error = mean_squared_error(Y, Y_pred)
print("Training Error:", error)
# Out:
# Training Error: 62.60851782044834

# %%
from scipy.optimize import minimize
import numpy as np

def inverse_predict(Y_target, model):
    def objective(x):
        x = np.array(x).reshape(1, -1)
        y_pred = model.predict(x)
        return np.mean((y_pred - Y_target) ** 2)

    # Initial guess (midpoint of each range)
    x0 = np.array([55.0, 40.0, 5.0, 8.0, 3.0])  # Midpoints

    # Explicitly defined bounds for the 5 features
    bounds = [
        (50.0, 60.0),      # Feature 1
        (37.5, 42.5),      # Feature 2
        (4.0, 6.0),   # Feature 3
        (6.0, 10.0),      # Feature 4
        (1.0, 5.0)   # Feature 5
    ]

    result = minimize(objective, x0, bounds=bounds)
    return result.x

# %%
Y_target = np.array([100, 100, 100, 100, 100, 100, 100, 100])  # your desired 11-output vector
X_estimated = inverse_predict(Y_target, model)
print("Estimated input features:", X_estimated)
# Out:
# Estimated input features: [60.  37.5  6.  10.   5. ]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# ...
